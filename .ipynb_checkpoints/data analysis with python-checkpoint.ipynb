# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('Provisional_COVID-19_Death_Counts_by_Week_Ending_Date_and_State.csv')

# %%
data
# Out:
#       Data as of  Start Date    End Date     Group       Year  Month  \
# 0     04/08/2021  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 1     04/08/2021  01/05/2020  01/11/2020   By Week       2020    NaN
# 2     04/08/2021  01/12/2020  01/18/2020   By Week       2020    NaN
# 3     04/08/2021  01/19/2020  01/25/2020   By Week       2020    NaN
# 4     04/08/2021  01/26/2020  02/01/2020   By Week       2020    NaN
# ...          ...         ...         ...       ...        ...    ...
# 4585  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
# 4586  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
# 4587  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
# 4588  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
# 4589  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
#
#       MMWR Week Week Ending Date          State  COVID-19 Deaths  \
# 0           1.0       01/04/2020  United States              1.0
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.State
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
#             ...
# 4585       Washington
# 4586    West Virginia
# 4587        Wisconsin
# 4588          Wyoming
# 4589      Puerto Rico
# Name: State, Length: 4590, dtype: object

# %%
type(data.State)
# Out:
# pandas.core.series.Series

# %%
#compare the states by total death

# %%
data.State == 'United States'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4585    False
# 4586    False
# 4587    False
# 4588    False
# 4589    False
# Name: State, Length: 4590, dtype: bool

# %%
date = data.'Week Ending Date'
# Out:
#   File "<ipython-input-18-d73a8fa8737a>", line 1
#     date = data.'Week Ending Date'
#                 ^
# SyntaxError: invalid syntax

# %%
state = data.State

# %%
date = data.WeekEndingDate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-2b990e5e4829> in <module>
# ----> 1 date = data.WeekEndingDate
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'WeekEndingDate'

# %%
date = data.Week Ending Date
# Out:
#   File "<ipython-input-21-e50c2edd8f93>", line 1
#     date = data.Week Ending Date
#                      ^
# SyntaxError: invalid syntax

# %%
data
# Out:
#       Data as of  Start Date    End Date     Group       Year  Month  \
# 0     04/08/2021  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 1     04/08/2021  01/05/2020  01/11/2020   By Week       2020    NaN
# 2     04/08/2021  01/12/2020  01/18/2020   By Week       2020    NaN
# 3     04/08/2021  01/19/2020  01/25/2020   By Week       2020    NaN
# 4     04/08/2021  01/26/2020  02/01/2020   By Week       2020    NaN
# ...          ...         ...         ...       ...        ...    ...
# 4585  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
# 4586  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
# 4587  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
# 4588  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
# 4589  04/08/2021  01/01/2020  04/03/2021  By Total        NaN    NaN
#
#       MMWR Week Week Ending Date          State  COVID-19 Deaths  \
# 0           1.0       01/04/2020  United States              1.0
# ...

# %%
data = pd.read_csv('Provisional_COVID-19_Death_Counts_by_Week_Ending_Date_and_State.csv')

# %%
data
# Out:
#      Data as of  Start Date   End Date     Group       Year  Month  MMWR Week  \
# 0      4/8/2021  12/29/2019   1/4/2020   By Week  2019/2020    NaN        1.0
# 1      4/8/2021    1/5/2020  1/11/2020   By Week       2020    NaN        2.0
# 2      4/8/2021   1/12/2020  1/18/2020   By Week       2020    NaN        3.0
# 3      4/8/2021   1/19/2020  1/25/2020   By Week       2020    NaN        4.0
# 4      4/8/2021   1/26/2020   2/1/2020   By Week       2020    NaN        5.0
# ...         ...         ...        ...       ...        ...    ...        ...
# 4585   4/8/2021    1/1/2020   4/3/2021  By Total        NaN    NaN        NaN
# 4586   4/8/2021    1/1/2020   4/3/2021  By Total        NaN    NaN        NaN
# 4587   4/8/2021    1/1/2020   4/3/2021  By Total        NaN    NaN        NaN
# 4588   4/8/2021    1/1/2020   4/3/2021  By Total        NaN    NaN        NaN
# 4589   4/8/2021    1/1/2020   4/3/2021  By Total        NaN    NaN        NaN
#
# ...

# %%
date = data.Week-Ending-Date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-d49343dbad51> in <module>
# ----> 1 date = data.Week-Ending-Date
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Week'

# %%
date = data.WeekDate

# %%
date
# Out:
# 0        1/4/2020
# 1       1/11/2020
# 2       1/18/2020
# 3       1/25/2020
# 4        2/1/2020
#           ...
# 4585          NaN
# 4586          NaN
# 4587          NaN
# 4588          NaN
# 4589          NaN
# Name: WeekDate, Length: 4590, dtype: object

# %%
df1 = pd.Series(data.State).value_counts() #frequency distribution of the states in the data

# %%
df1
# Out:
# Pennsylvania            85
# South Dakota            85
# Texas                   85
# Arkansas                85
# Virginia                85
# Georgia                 85
# New Hampshire           85
# Indiana                 85
# Idaho                   85
# Nevada                  85
# Missouri                85
# United States           85
# Colorado                85
# Arizona                 85
# Oklahoma                85
# South Carolina          85
# New Mexico              85
# Maine                   85
# Washington              85
# New Jersey              85
# North Carolina          85
# Vermont                 85
# Iowa                    85
# Illinois                85
# Hawaii                  85
# District of Columbia    85
# Nebraska                85
# Louisiana               85
# Wyoming                 85
# Minnesota               85
# Alaska                  85
# Mississippi             85
# Massachusetts           85
# Alabama                 85
# ...

# %%
count of states = pd.Series(df1).value_counts()
# Out:
#   File "<ipython-input-37-efefa1f15f8e>", line 1
#     count of states = pd.Series(df1).value_counts()
#           ^
# SyntaxError: invalid syntax

# %%
countofstates = pd.Series(df1).value_counts() #Number of states in the dataset

# %%
countofstates
# Out:
# 85    54
# Name: State, dtype: int64

# %%
pn = data[data.State == 'Pennsylvania']

# %%
pn
# Out:
#      Data as of  Start Date    End Date     Group       Year  Month  \
# 2640   4/8/2021  12/29/2019    1/4/2020   By Week  2019/2020    NaN
# 2641   4/8/2021    1/5/2020   1/11/2020   By Week       2020    NaN
# 2642   4/8/2021   1/12/2020   1/18/2020   By Week       2020    NaN
# 2643   4/8/2021   1/19/2020   1/25/2020   By Week       2020    NaN
# 2644   4/8/2021   1/26/2020    2/1/2020   By Week       2020    NaN
# ...         ...         ...         ...       ...        ...    ...
# 4218   4/8/2021    3/1/2021   3/31/2021  By Month       2021    3.0
# 4219   4/8/2021    4/1/2021    4/3/2021  By Month       2021    4.0
# 4508   4/8/2021    1/1/2020  12/31/2020   By Year       2020    NaN
# 4509   4/8/2021    1/1/2021    4/3/2021   By Year       2021    NaN
# 4576   4/8/2021    1/1/2020    4/3/2021  By Total        NaN    NaN
#
#       MMWR Week   WeekDate         State  COVID19Deaths  TotalDeaths  \
# 2640        1.0   1/4/2020  Pennsylvania            0.0       2784.0
# ...

# %%
 
sd = data[data.State == 'South Dakota']

# %%
plt.plot(pn.weekdate, pn.TotalDeaths)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-26fe137238df> in <module>
# ----> 1 plt.plot(pn.weekdate, pn.TotalDeaths)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'weekdate'

# %%
plt.plot(pn.COVID19Deaths, pn.TotalDeaths, 'o')

# %%
plt.plot(pn.year, pn.TotalDeaths, 'o')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-8f5365459038> in <module>
# ----> 1 plt.plot(pn.year, pn.TotalDeaths, 'o')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'year'
